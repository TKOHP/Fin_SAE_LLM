# %%
from datasets import load_dataset,Dataset
from transformers import AutoTokenizer
# Out:
# D:\tools\anaconda3\envs\llm_test\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
# 加载数据集
dataset = load_dataset('D:/project/dataset/FinCorpus',data_files={"train":'D:/project/dataset/FinCorpus/**/announcement_data.jsonl.gz'},cache_dir="E:/.cache",split=None)
# dataset = Dataset.from_json('D:/project/dataset/FinCorpus/announcement_data.jsonl.gz',cache_dir="E:/.cache",split=None)
# 查看第一个示例
print("第一个示例:")
print(dataset["train"][0])
print()
# Out:
# 第一个示例:
# {'text': '此次航行中，该船舶燃料消耗量(包括安全系数在内)为()吨。\nA、155\nB、225\nC、295\nD、345\nE、465\n答案：D\n分析解释：航行时燃料消耗定额\\*航行天数+停泊时燃料消耗定额\\*停泊天数=40\\*8.25+15\\*1=345吨', 'meta': {'source': 'fin_exam'}}

# %%
print(dataset["train"][102])
# Out:
# {'text': '对风险承受的正确理解是（）。\nA、风险承受都是不明智的选择\nB、如果承受费高于保险费，则选择风险自留\nC、在风险可以回避或转移的情况下，风险承受也是一种选择\nD、如果投资机会很好，则不选择风险承受\n答案：C\n分析解释：A特定情况下风险承受是一种明智的选择；B此时会选择保险，而不是风险承受；D投资机会好，会选择风险承受。', 'meta': {'source': 'fin_exam'}}
# {'text': '短期融资券的发行人为金融企业，发行和交易对象是银行间债券市场的机构投资者。（）\nA、错\nB、对\n答案：A\n分析解释：短期融资券的发行人为非金融企业，发行和交易的对象是银行间债券市场的机构投资者，不向社会公众发行和交易。', 'meta': {'source': 'fin_exam'}}
# {'text': '甲、乙两公司因技术秘密转让合同的履行发生纠纷，甲公司诉至人民法院。因本案涉及商业秘密，下列关于本案的说法中，正确的是（ ）\nA、该案不应当公开审理，但应当公开宣判\nB、经甲公司申请可以不公开审理，但应当公开宣判\nC、该案不应当公开审理和公开宣判\nD、该案应当公开审理和公开宣判\n答案：B\n分析解释：涉及商业秘密的案件，当事人申请不公开审理的，可以不公开审理。公开审理与不公开审理的案件，一律公开宣判。', 'meta': {'source': 'fin_exam'}}

# %%
# 查看数据集文本的数量
train_size = len(dataset['train'])

print(f"训练集大小: {train_size}")

print()
# Out:
# 训练集大小: 498043

# %%
# 使用分词器将文本分为token并查看token数量
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
total_token=4096*10_000
count=0
i=0
# 查看前5个样本的token数量
while i<10000:
    
    text = dataset['train'][i]['text']
    tokens = tokenizer.tokenize(text)
    token_ids = tokenizer.convert_tokens_to_ids(tokens)
    print(f"示例 {i + 1}:")
    # print(f"文本: {text}")
    print(f"token 数量: {len(tokens)}")
    print()
    i+=1
    count+=len(tokens)
    print(count)
# print(i)
print(count/i)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (587 > 512). Running this sequence through the model will result in indexing errors
# 示例 1:
# token 数量: 100
#
# 100
# 示例 2:
# token 数量: 150
#
# 250
# 示例 3:
# token 数量: 147
#
# 397
# 示例 4:
# token 数量: 150
#
# 547
# 示例 5:
# token 数量: 164
#
# 711
# 示例 6:
# token 数量: 131
#
# 842
# 示例 7:
# token 数量: 134
#
# 976
# 示例 8:
# token 数量: 134
#
# 1110
# 示例 9:
# token 数量: 85
#
# 1195
# 示例 10:
# token 数量: 118
#
# 1313
# 示例 11:
# token 数量: 147
#
# 1460
# 示例 12:
# token 数量: 271
#
# 1731
# 示例 13:
# token 数量: 96
#
# 1827
# 示例 14:
# token 数量: 107
#
# 1934
# 示例 15:
# token 数量: 184
#
# 2118
# 示例 16:
# token 数量: 136
#
# 2254
# 示例 17:
# token 数量: 129
#
# 2383
# 示例 18:
# token 数量: 138
#
# 2521
# 示例 19:
# token 数量: 119
#
# 2640
# 示例 20:
# token 数量: 126
#
# 2766
# 示例 21:
# token 数量: 190
#
# 2956
# 示例 22:
# token 数量: 115
#
# 3071
# 示例 23:
# token 数量: 160
#
# 3231
# 示例 24:
# token 数量: 121
#
# 3352
# 示例 25:
# ...
